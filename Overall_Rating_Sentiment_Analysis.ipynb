# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("googleplaystore_user_reviews.csv")

# %%
df.sample()
# Out:
#                            App Translated_Review Sentiment  \
# 50578  Fuelio: Gas log & costs           Perfect  Positive
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 50578                 1.0                     1.0

# %%
df.isna().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df.sample(5)
# Out:
#                                                App  \
# 61526               Herpes Positive Singles Dating
# 9540   AutoScout24 Switzerland – Find your new car
# 35645                              Dominos Game ✔️
# 35926                Down Dog: Great Yoga Anywhere
# 19362                CBS - Full Episodes & Live TV
#
#                                        Translated_Review Sentiment  \
# 61526  Works good far. Wish I could find free dating ...  Positive
# 9540                                         Card great!  Positive
# 35645                             love game ahmm problem  Positive
# 35926  Legit best yoga I could find. I always feel li...  Positive
# 19362                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 61526            0.500000                   0.775
# 9540             1.000000                   0.750
# 35645            0.050000                   0.500
# 35926            0.388889                   0.350
# 19362                 NaN                     NaN

# %%
df = df[~df.Sentiment.isna()]
df.isna().sum()
# Out:
# App                       0
# Translated_Review         5
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
df.Sentiment.value_counts()
# Out:
# Positive    23998
# Negative     8271
# Neutral      5163
# Name: Sentiment, dtype: int64

# %%
scores = df.Sentiment.map({"Positive":4,"Negative":-4,"Neutral":0})
df.Sentiment = scores

# %%
df.sample(3)
# Out:
#                                    App  \
# 33004  Daily Yoga - Yoga Fitness Plans
# 58597            HD Movie Video Player
# 44836                        Fast News
#
#                                        Translated_Review  Sentiment  \
# 33004  I using last 3 days continue use. This amazing...          4
# 58597  tried searching movies wanted watch trailers e...          4
# 44836  It gives prominent news different sources loca...          4
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 33004            0.198889                0.573333
# 58597            0.350000                0.550000
# 44836            0.250000                0.733333

# %%
df.sample(5)
# Out:
#                                 App  \
# 48434                Four In A Line
# 9146                       Arrow.io
# 58726       HDFC Bank MobileBanking
# 56091                   Google News
# 2416   ABC Kids - Tracing & Phonics
#
#                                        Translated_Review  Sentiment  \
# 48434     Esududidududud The first thing I done enjoy i4          4
# 9146                                              Killer          0
# 58726  Just I've uninstalled reinstalled Even date.st...         -4
# 56091  Still dark mode especially dark widget? And wo...          4
# 2416   My 5yo instantly loved game! I helped twice, l...          4
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 48434            0.325000                0.416667
# 9146             0.000000                0.000000
# 58726           -1.000000                1.000000
# 56091            0.062500                0.375000
# 2416             0.181385                0.641126

# %%
df.drop(columns=['Translated_Review','Sentiment_Polarity','Sentiment_Subjectivity'],inplace=True)

# %%
df.sample(5)
# Out:
#                                              App  Sentiment
# 37253                                    Dropbox          4
# 50622                    Fuelio: Gas log & costs          0
# 57694  Groupon - Shop Deals, Discounts & Coupons          4
# 55810                   Google Handwriting Input         -4
# 28277                      ColorSnap® Visualizer          4

# %%
after_editing = df.groupby('App').mean().reset_index()
after_editing.sample(5)
# Out:
#                               App  Sentiment
# 649                Four In A Line   2.819672
# 575        Facebook Pages Manager  -0.235294
# 828  High Blood Pressure Symptoms   2.486486
# 612               Financial Times   2.133333
# 170      Babbel – Learn Languages   2.583333

# %%
after_editing.sort_values(by='Sentiment',ascending=False)[:10]
# Out:
#                                                    App  Sentiment
# 439                           Daniel Tiger for Parents        4.0
# 755                                      Google Primer        4.0
# 321                                        Caller ID +        4.0
# 440                                   DashClock Widget        4.0
# 404                          Couple - Relationship App        4.0
# 220                     Best Fiends - Free Puzzle Game        4.0
# 320  CallApp: Caller ID, Blocker & Phone Call Recorder        4.0
# 497  Drawing for Kids Learning Games for Toddlers a...        4.0
# 496                            Draw a Stickman: EPIC 2        4.0
# 316                     Calendar+ Schedule Planner App        4.0

# %%
after_editing.sort_values(by='Sentiment')[:10]
# Out:
#                                 App  Sentiment
# 493                 Draw A Stickman  -4.000000
# 495                  Draw Your Game  -4.000000
# 494                         Draw In  -4.000000
# 467                 Discover Mobile  -4.000000
# 665       Free Live Talk-Video Call  -4.000000
# 424                DEER HUNTER 2018  -4.000000
# 319  Call of Duty:Black Ops Zombies  -4.000000
# 679     Fruit Block - Puzzle Legend  -4.000000
# 757              Google Street View  -3.000000
# 837    Hitwe - meet people and chat  -2.222222

# %%
df.head()
# Out:
#                      App  Sentiment
# 0  10 Best Foods for You          4
# 1  10 Best Foods for You          4
# 3  10 Best Foods for You          4
# 4  10 Best Foods for You          4
# 5  10 Best Foods for You          4

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
len(df.App.unique())
# Out:
# 9660

# %%
df[df.App == "Angry Birds Classic"]
# Out:
#                       App Category  Rating  Reviews Size      Installs  Type  \
# 1680  Angry Birds Classic     GAME     4.4  5566669  97M  100,000,000+  Free
# 1740  Angry Birds Classic     GAME     4.4  5566805  97M  100,000,000+  Free
# 1905  Angry Birds Classic     GAME     4.4  5566889  97M  100,000,000+  Free
# 1990  Angry Birds Classic     GAME     4.4  5566908  97M  100,000,000+  Free
# 3883  Angry Birds Classic     GAME     4.4  5565856  97M  100,000,000+  Free
#
#      Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 1680     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up
# 1740     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up
# 1905     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up
# 1990     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up
# 3883     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.App == "Angry Birds Classic"]
# Out:
#                       App Category  Rating  Reviews Size      Installs  Type  \
# 1680  Angry Birds Classic     GAME     4.4  5566669  97M  100,000,000+  Free
# 1740  Angry Birds Classic     GAME     4.4  5566805  97M  100,000,000+  Free
# 1905  Angry Birds Classic     GAME     4.4  5566889  97M  100,000,000+  Free
# 1990  Angry Birds Classic     GAME     4.4  5566908  97M  100,000,000+  Free
# 3883  Angry Birds Classic     GAME     4.4  5565856  97M  100,000,000+  Free
#
#      Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 1680     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up
# 1740     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up
# 1905     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up
# 1990     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up
# 3883     0       Everyone  Arcade  May 24, 2018       7.9.3  4.1 and up

# %%
len(df.App.unique())
# Out:
# 9660

# %%
df.drop(columns=['Current Ver','Android Ver','Content Rating','Genres','Price'], inplace = True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type      Last Updated
# 0     159   19M      10,000+  Free   January 7, 2018
# 1     967   14M     500,000+  Free  January 15, 2018
# 2   87510  8.7M   5,000,000+  Free    August 1, 2018
# 3  215644   25M  50,000,000+  Free      June 8, 2018
# 4     967  2.8M     100,000+  Free     June 20, 2018

# %%
df.dropna(inplace= True)

# %%
len(after_editing)
# Out:
# 865

# %%
df['Sentiment'] = np.NaN  #created a field called sentiment with initial value not a number(NaN)

# %%
df.sample(10)
# Out:
#                                                      App        Category  \
# 10213  Who Viewed My Facebook Profile - Stalkers Visi...          SOCIAL
# 8050                                            Avaya CX        BUSINESS
# 4587                                              Tinder       LIFESTYLE
# 9023                                     Direct Express®         FINANCE
# 1169                                 Capital One® Mobile         FINANCE
# 5665                                   Au-allstar for KR            GAME
# 5389                      My Boo - Your Virtual Pet Game          FAMILY
# 9266                                              SCS eC    PRODUCTIVITY
# 1508                      Homesnap Real Estate & Rentals  HOUSE_AND_HOME
# 217                         ViettelPost express delivery        BUSINESS
#
#        Rating  Reviews  Size      Installs  Type      Last Updated  Sentiment
# 10213     4.6   273244  9.9M    5,000,000+  Free     June 24, 2018        NaN
# 8050      4.4       21   21M        1,000+  Free     July 25, 2018        NaN
# 4587      4.0  2789775   68M  100,000,000+  Free    August 2, 2018        NaN
# 9023      4.5     6156  6.6M      500,000+  Free       May 9, 2017        NaN
# 1169      4.6   510401   79M   10,000,000+  Free    August 1, 2018        NaN
# 5665      3.6     2433   47M      100,000+  Free     June 15, 2018        NaN
# 5389      4.4   899748   80M   10,000,000+  Free    August 3, 2018        NaN
# 9266      4.4        7   17M          100+  Free  October 21, 2016        NaN
# 1508      4.3     3834   30M      500,000+  Free     July 31, 2018        2.0
# 217       4.4     1225   25M      100,000+  Free    August 1, 2018        NaN

# %%
x = list(after_editing.App)
for i in range(len(df)):
    check = df.iloc[i,0]
    if check in x:
        df.iloc[i,-1] = int(after_editing[after_editing.App == check].Sentiment)

# %%
after_editing[after_editing.App == '10 Best Foods for You']
# Out:
#                      App  Sentiment
# 0  10 Best Foods for You   3.134021

# %%
df.drop(columns='Category',inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates(subset=['App'],inplace=True)

# %%
df.sample(10)
# Out:
#                            App  Rating  Reviews  Size      Installs  Type  \
# 827    Lerni. Learn languages.     4.0     3847  6.9M      500,000+  Free
# 7717                        CQ     3.7        7  3.4M        1,000+  Free
# 3414     Galaxy Live Wallpaper     4.2    58052  4.0M    5,000,000+  Free
# 5569  【Miku AR Camera】Mikuture     4.4    36268   41M    1,000,000+  Free
# 3958           MORTAL KOMBAT X     4.4  3039889   18M   10,000,000+  Free
# 6602               Wireless BP     1.8       30  887k          500+  Free
# 633      Spine- The dating app     5.0        5  9.3M          500+  Free
# 3193                 Lufthansa     3.6    14544   43M    1,000,000+  Free
# 9726       Gate Of Death Ep: 1     4.4        7   34M          100+  Free
# 2664           Amazon Shopping     4.3   909226   42M  100,000,000+  Free
#
#             Last Updated  Sentiment
# 827     October 25, 2017        NaN
# 7717        May 18, 2018        NaN
# 3414  September 14, 2017        NaN
# 5569      April 25, 2017        NaN
# 3958       June 27, 2018        NaN
# 6602        May 27, 2016        NaN
# 633        July 14, 2018        NaN
# 3193       July 27, 2018        NaN
# 9726     October 7, 2016        NaN
# 2664       July 31, 2018        0.0

# %%
df[df.App=="8 Ball Pool"]
# Out:
#               App  Rating   Reviews Size      Installs  Type   Last Updated  \
# 1675  8 Ball Pool     4.5  14198297  52M  100,000,000+  Free  July 31, 2018
#
#       Sentiment
# 1675        0.0

# %%
df[df.App=="ROBLOX"]
# Out:
#          App  Rating  Reviews Size      Installs  Type   Last Updated  \
# 1653  ROBLOX     4.5  4447388  67M  100,000,000+  Free  July 31, 2018
#
#       Sentiment
# 1653        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8197 entries, 0 to 10840
# Data columns (total 8 columns):
# App             8197 non-null object
# Rating          8197 non-null float64
# Reviews         8197 non-null object
# Size            8197 non-null object
# Installs        8197 non-null object
# Type            8197 non-null object
# Last Updated    8197 non-null object
# Sentiment       816 non-null float64
# dtypes: float64(2), object(6)
# memory usage: 576.4+ KB

# %%
df = df[np.isfinite(df['Sentiment'])]

# %%
df.sort_values(by='Rating')
# Out:
#                                                     App  Rating  Reviews  \
# 2303                 11M   1,000,000+  Free       July 26, 2018        2.0
# 2081                 63M     100,000+  Free      August 6, 2018        2.0
# 1256                 15M  10,000,000+  Free       June 28, 2018        3.0
# 64                   27M     100,000+  Free        July 3, 2018        3.0
# 61                   17M     100,000+  Free        July 3, 2018        3.0
# 1336                 12M     500,000+  Free        May 17, 2018        4.0
#
# [816 rows x 8 columns]

# %%
df.sort_values(by='Sentiment',ascending=False)[:5]
# Out:
#                                 App  Rating Reviews                Size  \
# 1336  Down Dog: Great Yoga Anywhere     4.9   28945                 12M
# 3300           Calculator Plus Free     4.6  679912  Varies with device
# 2067        Baby Panda’s Juice Shop     4.5   19230                 45M
# 3114  Google Trips - Travel Planner     4.1   26871  Varies with device
# 3534                  Google Slides     4.2  244567  Varies with device
#
#           Installs  Type    Last Updated  Sentiment
# 1336      500,000+  Free    May 17, 2018        4.0
# 3300   10,000,000+  Free   July 27, 2018        4.0
# 2067    5,000,000+  Free   July 12, 2018        4.0
# 3114    5,000,000+  Free   July 26, 2018        4.0
# 3534  100,000,000+  Free  August 6, 2018        4.0

# %%
df[~df.Sentiment.isna()].sort_values(by='Sentiment')[:5]
# Out:
#                                  App  Rating Reviews  Size     Installs  Type  \
# 692        Free Live Talk-Video Call     4.7     158  4.5M      10,000+  Free
# 1777                         Draw In     4.2   46416   73M  10,000,000+  Free
# 1837  Call of Duty:Black Ops Zombies     4.2   13004   46M     100,000+  Paid
# 3938                 Draw A Stickman     3.4   29265   17M   1,000,000+  Free
# 1994     Fruit Block - Puzzle Legend     4.6  125647   33M  10,000,000+  Free
#
#            Last Updated  Sentiment
# 692        July 5, 2018       -4.0
# 1777      July 23, 2018       -4.0
# 1837  December 20, 2016       -4.0
# 3938       May 19, 2017       -4.0
# 1994      July 23, 2018       -4.0

# %%
df.drop(columns=['Reviews','Size','Installs','Type','Last Updated'], inplace = True)

# %%
df.head()
# Out:
#                                           App  Rating  Sentiment
# 1                         Coloring book moana     3.9        1.0
# 8                        Garden Coloring Book     4.4        2.0
# 18              FlipaClip - Cartoon animation     4.3        4.0
# 21  Boys Photo Editor - Six Pack & Men's Suit     4.1        1.0
# 26              Colorfit - Drawing & Coloring     4.7        2.0

# %%
df['mean'] = df.mean(axis=1)

# %%
df.sort_values(by='Sentiment',ascending=False)[:5]
# Out:
#                                 App  Rating  Sentiment  mean
# 1336  Down Dog: Great Yoga Anywhere     4.9        4.0  4.45
# 3300           Calculator Plus Free     4.6        4.0  4.30
# 2067        Baby Panda’s Juice Shop     4.5        4.0  4.25
# 3114  Google Trips - Travel Planner     4.1        4.0  4.05
# 3534                  Google Slides     4.2        4.0  4.10

# %%
df.sort_values(by='Sentiment')[:5]
# Out:
#                                  App  Rating  Sentiment  mean
# 692        Free Live Talk-Video Call     4.7       -4.0  0.35
# 1777                         Draw In     4.2       -4.0  0.10
# 1837  Call of Duty:Black Ops Zombies     4.2       -4.0  0.10
# 3938                 Draw A Stickman     3.4       -4.0 -0.30
# 1994     Fruit Block - Puzzle Legend     4.6       -4.0  0.30

# %%
df.sort_values(by='Rating')[:5]
# Out:
#                                                    App  Rating  Sentiment  \
# 2487                                Anthem BC Anywhere     2.6        0.0
# 2317                                   Anthem Anywhere     2.7        0.0
# 2337                                      Delta Dental     3.0       -1.0
# 915   Acorn TV: World-class TV from Britain and Beyond     3.0        1.0
# 3483                                          HTC Mail     3.1        1.0
#
#       mean
# 2487  1.30
# 2317  1.35
# 2337  1.00
# 915   2.00
# 3483  2.05

# %%
df.sort_values(by='Sentiment', ascending=False)[:5]
# Out:
#                                 App  Rating  Sentiment  mean
# 1336  Down Dog: Great Yoga Anywhere     4.9        4.0  4.45
# 3300           Calculator Plus Free     4.6        4.0  4.30
# 2067        Baby Panda’s Juice Shop     4.5        4.0  4.25
# 3114  Google Trips - Travel Planner     4.1        4.0  4.05
# 3534                  Google Slides     4.2        4.0  4.10

# %%
df = df.rename(columns={'mean': 'Overall Rating'})

# %%
df.sort_values(by='Sentiment',ascending=False)[:5]
# Out:
#                                 App  Rating  Sentiment  Overall Rating
# 1336  Down Dog: Great Yoga Anywhere     4.9        4.0            4.45
# 3300           Calculator Plus Free     4.6        4.0            4.30
# 2067        Baby Panda’s Juice Shop     4.5        4.0            4.25
# 3114  Google Trips - Travel Planner     4.1        4.0            4.05
# 3534                  Google Slides     4.2        4.0            4.10

# %%
df.sort_values(by='Sentiment')[:5]
# Out:
#                                  App  Rating  Sentiment  Overall Rating
# 692        Free Live Talk-Video Call     4.7       -4.0            0.35
# 1777                         Draw In     4.2       -4.0            0.10
# 1837  Call of Duty:Black Ops Zombies     4.2       -4.0            0.10
# 3938                 Draw A Stickman     3.4       -4.0           -0.30
# 1994     Fruit Block - Puzzle Legend     4.6       -4.0            0.30

# %%
df.sort_values(by='Rating', ascending=False)[:5]
# Out:
#                                         App  Rating  Sentiment  Overall Rating
# 64    DMV Permit Practice Test 2018 Edition     4.9        3.0            3.95
# 1336          Down Dog: Great Yoga Anywhere     4.9        4.0            4.45
# 61           CDL Practice Test 2018 Edition     4.9        3.0            3.95
# 1268    Home Workout for Men - Bodybuilding     4.8        3.0            3.90
# 2803     FreePrints – Free Photos Delivered     4.8        3.0            3.90

# %%
df.sort_values(by='Rating')[:5]
# Out:
#                                                    App  Rating  Sentiment  \
# 2487                                Anthem BC Anywhere     2.6        0.0
# 2317                                   Anthem Anywhere     2.7        0.0
# 2337                                      Delta Dental     3.0       -1.0
# 915   Acorn TV: World-class TV from Britain and Beyond     3.0        1.0
# 3483                                          HTC Mail     3.1        1.0
#
#       Overall Rating
# 2487            1.30
# 2317            1.35
# 2337            1.00
# 915             2.00
# 3483            2.05

# %%
df.head()
# Out:
#                                           App  Rating  Sentiment  \
# 1                         Coloring book moana     3.9        1.0
# 8                        Garden Coloring Book     4.4        2.0
# 18              FlipaClip - Cartoon animation     4.3        4.0
# 21  Boys Photo Editor - Six Pack & Men's Suit     4.1        1.0
# 26              Colorfit - Drawing & Coloring     4.7        2.0
#
#     Overall Rating
# 1             2.45
# 8             3.20
# 18            4.15
# 21            2.55
# 26            3.35

# %%
df.sample(5)
# Out:
#                            App  Rating  Sentiment  Overall Rating
# 5393  Diary with lock password     4.3        2.0            3.15
# 1181              Easy Recipes     4.7        1.0            2.85
# 1658    Hello Kitty Nail Salon     4.2        0.0            2.10
# 1220          Cookbook Recipes     4.1        3.0            3.55
# 3235          Google Translate     4.4        4.0            4.20
